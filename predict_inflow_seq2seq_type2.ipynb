# %%
""" Seq2Seq prediction : Type 2"""
# import libraries

import numpy as np
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from sklearn.preprocessing import StandardScaler, MinMaxScaler
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.layers import Input, LSTM, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping
import matplotlib.pyplot as plt

# %%
# data loading 

rain_data = pd.read_csv('rain_day.csv', encoding='utf-8')
dam_data = pd.read_csv('dam.csv', encoding='utf-8')

# %%
""" data making part1 : clip data [2000.01.01 - 2023.12.31]"""
# 2000.01.01 = 9496 
rain_data = rain_data[9496:]

""" data making part2 : making date, dam & rain data """
# data
data = pd.merge(dam_data, rain_data, on='date', how='inner')
data = data.fillna(0)

# cols
rain_cols = list(data)[2:]
dam_cols = list(data)[1]
cols = list(data)[1:]

# rain
rain = data[rain_cols]

# dam
dam = data[['inflow']]

# date
dates = pd.to_datetime(data['date'])

# not date data
data_float = data[cols].astype(float)

# %%
cols
# Out:
# ['inflow', '90', '100', '101', '211', '212']

# %%
""" data making part3 : using scaler each data(dam & rain) """
# rain scaler
scaler_rain = MinMaxScaler(feature_range = (0,1))
rain_scaled = scaler_rain.fit_transform(rain)

# dam scaler
scaler_dam = MinMaxScaler(feature_range = (0,1))
dam_scaled = scaler_dam.fit_transform(dam)

# put two scaled data to one
data_scaled = np.hstack((dam_scaled, rain_scaled))
data_scaled_df = pd.DataFrame(data_scaled, columns=cols, index=data.index)

# %%
data_scaled_df
# Out:
#         inflow        90       100       101       211       212
# 0     0.003778  0.003255  0.001404  0.000000  0.000000  0.000000
# 1     0.004848  0.002983  0.004351  0.033905  0.027778  0.035225
# 2     0.003802  0.000000  0.000000  0.000000  0.000000  0.000000
# 3     0.003256  0.000000  0.000000  0.000000  0.000000  0.000000
# 4     0.005204  0.028207  0.012772  0.045714  0.023016  0.046967
# ...        ...       ...       ...       ...       ...       ...
# 8761  0.006148  0.000000  0.000000  0.000000  0.000000  0.000000
# 8762  0.005034  0.000000  0.000000  0.000000  0.000000  0.000000
# 8763  0.004963  0.000000  0.000000  0.000000  0.000000  0.000000
# 8764  0.006935  0.001899  0.003228  0.037714  0.026984  0.033268
# 8765  0.006132  0.072688  0.008421  0.020190  0.012302  0.019178
#
# [8766 rows x 6 columns]

# %%
""" data making part4 : making sequence to fit the model """
def create_sequences(data, features, target, seq_length):
    X, y = [], []
    for i in range(len(data) - (seq_length)):
        X.append(data[features].iloc[i:i+seq_length].values)
        y.append(data[target].iloc[i:i+seq_length].values)
    return np.array(X), np.array(y)

# deciding sequence length
seq_len = 7
target = 'inflow'
features = rain_cols

# creating X,y data
X, y = create_sequences(data_scaled_df, features, target, seq_len)

# %%
""" data making part5 : making Train & Test """
# cutting off the dates by seq_len
adjusted_dates = dates[seq_len:]

# deviding data to "Train & Test"
# Train : 2000.01.01 - 2017.12.31
# Test : 2018.01.01 - 2023.12.31
train_mask = (adjusted_dates >= '2000-01-01') & (adjusted_dates <= '2017-12-31')
test_mask = (adjusted_dates >= '2018-01-01') & (adjusted_dates <= '2023-12-31')

# Train
trainX = X[train_mask]
trainY = y[train_mask]
train_dates = adjusted_dates[train_mask]

# Test
testX = X[test_mask]
testY = y[test_mask]
test_dates = adjusted_dates[test_mask]

# original dam data
train_dam = dam[seq_len:seq_len+len(trainY)]
test_dam = dam[len(trainY)+seq_len:]

# %%
""" data making part6 : Editing Train & Test shape """
trainX, trainY = np.array(trainX), np.array(trainY)
testX, testY = np.array(testX), np.array(testY)

# trainY와 testY: change dimension (N, output_steps, feature_dim) 
trainY = np.expand_dims(trainY, axis=-1)  # (6995, 21) → (6995, 21, 1)
testY = np.expand_dims(testY, axis=-1)    # (1749, 21) → (1749, 21, 1)

# print shape
print("Train : ", trainX.shape, trainY.shape)
print("Test : ", testX.shape, testY.shape)
print("Original dam : ", train_dam.shape, test_dam.shape)
# Out:
# Train :  (6568, 7, 5) (6568, 7, 1)
# Test :  (2191, 7, 5) (2191, 7, 1)
# Original dam :  (6568, 1) (2191, 1)

# %%
""" Model """

from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, LSTM, Dense

# Encoder
encoder_inputs = Input(shape=(trainX.shape[1], trainX.shape[2]))
encoder_lstm = LSTM(64, return_state=True)
encoder_outputs, state_h, state_c = encoder_lstm(encoder_inputs)

# Decoder
decoder_inputs = Input(shape=(trainX.shape[1], trainX.shape[2]))  # Decoder 입력이 seq_len개의 타임스텝
decoder_lstm = LSTM(64, return_sequences=True, return_state=True)
decoder_outputs, _, _ = decoder_lstm(decoder_inputs, initial_state=[state_h, state_c])

# Fully connected layer to generate predictions for each timestep
decoder_dense = Dense(1)  # 각 타임스텝마다 feature 예측
decoder_outputs = decoder_dense(decoder_outputs)

# Seq2Seq 모델
model = Model([encoder_inputs, decoder_inputs], decoder_outputs)
model.compile(optimizer='adam', loss='mse', metrics=['mae'])
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)      │ (None, 7, 5)              │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ input_layer_1 (InputLayer)    │ (None, 7, 5)              │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ lstm (LSTM)                   │ [(None, 64), (None, 64),  │          17,920 │ input_layer[0][0]          │
# │                               │ (None, 64)]               │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ lstm_1 (LSTM)                 │ [(None, 7, 64), (None,    │          17,920 │ input_layer_1[0][0],       │
# │                               │ 64), (None, 64)]          │                 │ lstm[0][1], lstm[0][2]     │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense (Dense)                 │ (None, 7, 1)              │              65 │ lstm_1[0][0]               │
# └───────────────────────────────┴───────────────────────────┴─────────────────┴────────────────────────────┘
#  Total params: 35,905 (140.25 KB)
#  Trainable params: 35,905 (140.25 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# EarlyStopping callback 
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

#Try to load weights
try:
    model.load_weights('7dam_s2s_type2.weights.h5')
    print("Loaded model weights from disk")
except:
    print("No weights found, training model from scratch")
    # Fit the model
    history = model.fit(
        [trainX, trainX],  # Encoder Input, Decoder Input
        trainY,            # Target Output
        validation_data=([testX, testX], testY),  # test data
        batch_size=32,     # batch size
        epochs=100,        # maximum epoch 
        callbacks=[early_stopping],  # EarlyStopping 
        verbose=1          # processing print
    )
    # Save model weights after training
    model.save_weights('7dam_s2s_type2.weights.h5')
    
    plt.plot(history.history['loss'], label='Training loss')
    plt.plot(history.history['val_loss'], label='Validation loss')
    plt.legend()
    plt.show()
# Out:
# No weights found, training model from scratch
# Epoch 1/100
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - loss: 0.0014 - mae: 0.0139 - val_loss: 8.1843e-04 - val_mae: 0.0117
# Epoch 2/100
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 8.3008e-04 - mae: 0.0123 - val_loss: 7.4992e-04 - val_mae: 0.0107
# Epoch 3/100
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 8.0944e-04 - mae: 0.0115 - val_loss: 7.5236e-04 - val_mae: 0.0101
# Epoch 4/100
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 6.9207e-04 - mae: 0.0109 - val_loss: 6.4471e-04 - val_mae: 0.0104
# Epoch 5/100
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 5.6953e-04 - mae: 0.0100 - val_loss: 6.7367e-04 - val_mae: 0.0092
# Epoch 6/100
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 6.2605e-04 - mae: 0.0098 - val_loss: 6.6481e-04 - val_mae: 0.0088
# Epoch 7/100
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 5.4701e-04 - mae: 0.0093 - val_loss: 6.5061e-04 - val_mae: 0.0093
# Epoch 8/100
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 5.0708e-04 - mae: 0.0093 - val_loss: 6.3963e-04 - val_mae: 0.0088
# Epoch 9/100
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 5.5111e-04 - mae: 0.0095 - val_loss: 6.4122e-04 - val_mae: 0.0091
# Epoch 10/100
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 6.0095e-04 - mae: 0.0099 - val_loss: 6.4734e-04 - val_mae: 0.0093
# Epoch 11/100
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 5.0571e-04 - mae: 0.0090 - val_loss: 6.4847e-04 - val_mae: 0.0090
# Epoch 12/100
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 4.6338e-04 - mae: 0.0089 - val_loss: 6.5531e-04 - val_mae: 0.0096
# Epoch 13/100
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 4.9625e-04 - mae: 0.0091 - val_loss: 6.3508e-04 - val_mae: 0.0086
# Epoch 14/100
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 4.5489e-04 - mae: 0.0087 - val_loss: 6.6790e-04 - val_mae: 0.0097
# Epoch 15/100
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 5.0885e-04 - mae: 0.0090 - val_loss: 6.8427e-04 - val_mae: 0.0086
# Epoch 16/100
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 4.6340e-04 - mae: 0.0088 - val_loss: 6.6399e-04 - val_mae: 0.0097
# Epoch 17/100
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 4.9556e-04 - mae: 0.0090 - val_loss: 6.5501e-04 - val_mae: 0.0093
# Epoch 18/100
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 4.3607e-04 - mae: 0.0085 - val_loss: 6.6782e-04 - val_mae: 0.0094
# Epoch 19/100
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 4.2070e-04 - mae: 0.0084 - val_loss: 6.9259e-04 - val_mae: 0.0095
# Epoch 20/100
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 4.8441e-04 - mae: 0.0090 - val_loss: 6.6367e-04 - val_mae: 0.0091
# Epoch 21/100
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 4.8381e-04 - mae: 0.0088 - val_loss: 6.6200e-04 - val_mae: 0.0086
# Epoch 22/100
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 4.0919e-04 - mae: 0.0083 - val_loss: 6.7738e-04 - val_mae: 0.0108
# Epoch 23/100
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 4.2124e-04 - mae: 0.0087 - val_loss: 7.1312e-04 - val_mae: 0.0093

# %%
""" Predict value """
train_pred = model.predict([trainX, trainX])
test_pred = model.predict([testX, testX])

""" applying inverse scaler : to original value """
# train
train_pred_inv = scaler_dam.inverse_transform(train_pred.reshape(-1,1))
trainY_inv = scaler_dam.inverse_transform(trainY.reshape(-1,1))

# test
test_pred_inv = scaler_dam.inverse_transform(test_pred.reshape(-1,1))
testY_inv = scaler_dam.inverse_transform(testY.reshape(-1,1))

""" if value is smaller than 0, change to 0 """
# Train post-processing 
train_pred_clipped = np.maximum(train_pred_inv, 0)
# Test post-processing
test_pred_clipped = np.maximum(test_pred_inv, 0)
# Out:
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
# print shape 
print(trainY.shape, train_pred_clipped.shape, testY_inv.shape, test_pred_clipped.shape)
print("Train data length : ", trainY.shape[0])
print("Test data length : ", testY.shape[0])

# print train / test dates
print("Train : ", train_dates.iloc[0].strftime('%Y-%m-%d'),"~",train_dates.iloc[-1].strftime('%Y-%m-%d'))
print("Test : ", test_dates.iloc[0].strftime('%Y-%m-%d'),"~",test_dates.iloc[-1].strftime('%Y-%m-%d'))
# Out:
# (6568, 7, 1) (45976, 1) (15337, 1) (15337, 1)
# Train data length :  6568
# Test data length :  2191
# Train :  2000-01-08 ~ 2017-12-31
# Test :  2018-01-01 ~ 2023-12-31

# %%
# pick last data in sequence 
trainY_edit = []
train_pred_edit = []
testY_edit = []
test_pred_edit = []

for i in range(seq_len-1,len(trainY_inv),seq_len):
    trainY_edit.append(trainY_inv[i])

for i in range(seq_len-1,len(train_pred_inv),seq_len):
    train_pred_edit.append(train_pred_clipped[i])

for i in range(seq_len-1,len(testY_inv),seq_len):
    testY_edit.append(trainY_inv[i])

for i in range(seq_len-1,len(test_pred_inv),seq_len):
    test_pred_edit.append(train_pred_clipped[i][-1])

# %%
""" Train graph part1"""
# Create the zoomed plot
plt.figure(figsize=(14, 5))

plt.plot(trainY_inv,
         color='blue',
         label='Observed Dam Flow')
plt.plot(train_pred_clipped,
         color='red',
         label='Predicted Dam Flow')

plt.xlabel('')
plt.ylabel('Dam Flow')
plt.title('Observed vs Predicted Dam Flow')
plt.legend()
plt.show()

# %%
""" Train graph part1-1"""
# Create the zoomed plot
plt.figure(figsize=(14, 5))

plt.plot(train_dates[:],
         trainY_edit[:],
         color='blue',
         label='Observed Dam Flow')
plt.plot(train_dates[:],
         train_pred_edit[:],
         color='red',
         label='Predicted Dam Flow')

plt.xlabel('Date')
plt.ylabel('Dam Flow')
plt.title('Observed vs Predicted Dam Flow')
plt.legend()
plt.show()

# %%
""" Train graph part2 """
# create 1:1 graph (after post-processing, trainY vs trainY_pred)
x = np.arange(0,4000)
y = x

plt.figure(figsize = (5,5))
plt.scatter(trainY_edit[:], train_pred_edit[:], color = 'purple', alpha = 0.6)
plt.plot(x,y, color = 'blue', alpha = 0.6, label = 'y = x')
plt.xlabel('Actuals')
plt.ylabel('Simulate')

plt.legend()
plt.show()

# %%
""" Test graph part1"""
# Create the zoomed plot
plt.figure(figsize=(14, 5))

plt.plot(testY_inv,
         color='blue',
         label='Observed Dam Flow')
plt.plot(test_pred_clipped,
         color='red',
         label='Predicted Dam Flow')

plt.xlabel('Date')
plt.ylabel('Dam Flow)')
plt.title('Observed vs Predicted Dam Flow')
plt.legend()
plt.show()

# %%
""" Train graph part1-1"""
# Create the zoomed plot
plt.figure(figsize=(14, 5))

plt.plot(test_dates[:],
         testY_edit[:],
         color='blue',
         label='Observed Dam Flow')
plt.plot(test_dates[:],
         test_pred_edit[:],
         color='red',
         label='Predicted Dam Flow')

plt.xlabel('Date')
plt.ylabel('Dam Flow')
plt.title('Observed vs Predicted Dam Flow')
plt.legend()
plt.show()

# %%
""" Test graph part2 """
# create 1:1 graph (after post-processing, trainY vs trainY_pred)
x = np.arange(0,4000)
y = x

plt.figure(figsize = (5,5))
plt.scatter(testY_edit[:], test_pred_edit[:], color = 'purple', alpha = 0.6)
plt.plot(x,y, color = 'blue', alpha = 0.6, label = 'y = x')
plt.xlabel('Actuals')
plt.ylabel('Simulate')

plt.legend()
plt.show()

# %%
""" Evaluation code """

# Replace these with your actual data
q_obs = testY_inv[:]
q_sim = test_pred_clipped[:]

#RMSE
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

rmse = np.sqrt(mean_squared_error(q_obs, q_sim))
print('RMSE : %6.2f' %(rmse))

# NSE
from numpy import mean
num_sum1 = 0
num_sum2 = 0
num_avg = mean(q_obs[:])
for i in range(len(q_obs)):
  num1 = q_obs[i] - q_sim[i]
  num_sum1 += num1**2
  num2 = q_obs[i] - num_avg
  num_sum2 += num2**2

nse = 1 - (num_sum1 / num_sum2)
print('NSE  : %6.2f' % nse.item())  # nse 배열에서 값을 추출해 스칼라로 변환

# PBIAS
num_sum1 = 0
for i in range(len(q_obs)):
  num1 = q_obs[i] - q_sim[i]
  num_sum1 += num1
    
# Calculate means
q_obs_mean = np.mean(q_obs)
q_sim_mean = np.mean(q_sim)

pbias = (num_sum1 / np.sum(q_obs[:])) * 100
print('PBIAS: %6.2f' % pbias.item())  # .item()으로 값을 추출

# Calculate numerator and denominators
numerator = np.sum((q_obs - q_obs_mean) * (q_sim - q_sim_mean))
denominator = np.sqrt(np.sum((q_obs - q_obs_mean)**2) * np.sum((q_sim - q_sim_mean)**2))

# Calculate R^2
R_squared = (numerator / denominator)**2

print("R^2  : %6.2f"%R_squared)
# Out:
# RMSE : 106.04
# NSE  :   0.71
# PBIAS:   9.10
# R^2  :   0.71
